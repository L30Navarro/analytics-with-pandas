# %% [markdown]
# # Estruturação e documentação dos dados de produção de cana-de-açúcar em Pandas.

# %%
# Carregar a biblioteca Pandas:
import pandas as pd

# %% [markdown]
# # 1 - Dicionário de Dados

# %% [markdown]
# Na célula abaixo será apresentado um script para a criação de um Dicionário de Dados referente aos dados da cana-de-açúcar, o qual será armazenado diretamente em um DataFrame, dispensando a necessidade de leitura de dados externos para a memória. </br>
# O DataFrame será estruturado com as colunas id_municipio (identificador do município), volume_produzido (volume de produção de cana-de-açúcar produzido nas microrregiões),  microrregiao (nome da microrregião geográfica do Brasil) e uf (unidade da federação do Brasil).

# %%
microrregiao_prod_df = pd.DataFrame({
    'id_microrregiao': ['35004','35010','35014','35036','35024','35013','50010','35039','35021','52015','31022','52013','31021','35017','35016','35018',
                        '52018','35020','35028','35005','35009','50011','35011','41001','35025','35025','35019','51013','41006','35015','52014','35030',
                        '41003','35027','35040','35034','52006','35035','35003','35007','35012','31017','35023','41002','31023','50005','35026','35029',
                        '35001','31018','35002','31002','35022','41016','35032','35006','51004','35037','50008','35043','35031','51022','52012','41015',
                        '35038','31026','50006','35046','41007','31047','31048','41005','51014','52009','29003','35042','31042','52007','51021','31001',
                        '50003','31024','31060','50004','41012','24003','31004','41013','31049','41009','41017','35041','42019','52017','52004','51018',
                        '41008','51005','41004','50007','31016','31005','41014','31044','41010','52003','41011','31007','35033','35050','31003','31015',
                        '31025','31062','31036','31031','31064','31035','31051','31027','52010','41018','31009','41023','31043','51015','41022','31037',
                        '31011','31040','31012','31028','31020','31065','31032','31063','41024','31046','35048','51006','31014','31058','51001','31066',
                        '31006','31059','31019','31041','31010','31045','31033','31013','31030','51017','31053','41026','31039','51016','31055','52008',
                        '31034','31056','31038','31029','52011','41019','41027','31054','41035','41025','31050','31057','31061','41028','31008','41038',
                        '35052','50009','35051','41029','41033','51010','52005','31052','35044','50002','52016','51012','35053','35047','51020','52002',
                        '35045','41037','41031','24007','51003','52001','50001','51011','51007','35055','51008','41020','41030','51019','35060','51002',
                        '35062','17003','51009','29017','41034','35061','35049','35058'],
    'volume_produzido': ['473721695','377615223','362846755','320732162','312307290','310754371','293544328','253622427','245591114','239380119','239341752',
                     '234537856','227733259','210628527','207235276','162131311','158711462','157117982','148571118','147276747','144847546',
                     '131969478','129727021','128652830','126353510','123684345','122011756','119994690','112956273','112113664','106927165','106782282',
                     '105182271','103092025','102287809','95001163','92708847','89571955','87286254','83822990','82509097','78673216','78167160','70952222',
                     '70873094','70051823','67860683','67156366','66941029','63946660','61297516','61250506','59698759','56877231','54068062','51931039',
                     '50395801','46810804','45527962','43618845','40574012','38203695','36827776','35927950','30521845','30507888','24971322','22698634',
                     '22429721','20988146','20674136','19783757','19133785','18734805','18726600','18322957','17752871','17125108','16660114','16313733',
                     '15827324','14896509','14713205','12636484','12434162','12299933','11340023','10259115','8699587','8318130','7757252','7585329',
                     '7354534','6681698','6538530','6260489','6171189','5976465','5874982','5076362','4804625','4256575','3866557','3862678','3699947',
                     '3425311','3191771','3159440','2698922','2445572','2180510','2090267','1900200','1880903','1821771','1776346','1750251','1748311',
                     '1745959','1703022','1492575','1457329','1323970','1262596','1259623','1157662','1035875','1032479','1022088','1018573','994022',
                     '989690','946665','898593','870078','827377','818162','766415','726561','706828','705648','682523','671173','647162','625407',
                     '621051','611115','601408','600948','568560','514646','508766','498673','487153','414823','375448','371829','369493','368295',
                     '368020','358709','333076','330985','316720','308995','297460','296654','273227','246274','229877','224742','216525','207742',
                     '201561','199326','198369','175170','142146','131859','127488','124311','119424','117770','103812','100256','97870','92800',
                     '91720','81517','77305','69470','53940','51500','44585','40339','36125','29784','23102','21078','20625','20620','19685',
                     '18119','17675','14965','14754','11937','10960','10300','8800','5600','4620','4025','2382','600','10'],                
    'microrregiao': ['São José do Rio Preto','São Joaquim da Barra','Ribeirão Preto','Presidente Prudente','Araraquara','Jaboticabal','Dourados',
                     'Assis','Jaú','Meia Ponte','Uberaba','Sudoeste de Goiás','Frutal','Araçatuba','Andradina','Birigui','Quirinópolis','Bauru',
                     'Piracicaba','Catanduva','Barretos','Iguatemi','Ituverava','Paranavaí','São Carlos','Novo Horizonte','Lins','Tangará da Serra',
                     'Astorga','Batatais','Vale do Rio dos Bois','São João da Boa Vista','Cianorte','Limeira','Ourinhos','Dracena','Ceres','Adamantina',
                     'Votuporanga','Nhandeara','Franca','Ituiutaba','Botucatu','Umuarama','Araxá','Cassilândia','Rio Claro','Pirassununga','Jales',
                     'Uberlândia','Fernandópolis','Paracatu','Avaré','Jacarezinho','Campinas','Auriflama','Parecis','Tupã','Nova Andradina','Tatuí',
                     'Mogi Mirim','Alto Araguaia','Entorno de Brasília','Cornélio Procópio','Marília','Bom Despacho','Paranaíba','Sorocaba','Porecatu',
                     'Passos','São Sebastião do Paraíso','Campo Mourão','Jauru','Anicuns','Santa Maria da Vitória','Itapetininga','Piuí','Anápolis',
                     'Rondonópolis','Unaí','Alto Taquari','Três Marias','Ponte Nova','Campo Grande','Faxinal','Médio Oeste','Janaúba','Ivaiporã',
                     'Alfenas','Maringá','Ibaiti','Itapeva','Criciúma','Catalão','Porangatu','Alto Pantanal','Floraí','Arinos','Goioerê','Três Lagoas',
                     'Nanuque','Salinas','Assaí','Formiga','Apucarana','Aragarças','Londrina','Montes Claros','Amparo','São José dos Campos','Januária',
                     'Teófilo Otoni','Curvelo','Viçosa','Peçanha','Itabira','Ubá','Guanhães','Poços de Caldas','Sete Lagoas','Goiânia','Wenceslau Braz',
                     'Bocaiúva','Cascavel','Divinópolis','Alto Paraguai','Toledo','Governador Valadares','Capelinha','Caratinga','Araçuaí',
                     'Conceição do Mato Dentro','Patos de Minas','Juiz de Fora','Itaguara','Muriaé','Foz do Iguaçu','Oliveira','Bragança Paulista',
                     'Alto Teles Pires','Almenara','São João Del Rei','Aripuanã','Cataguases','Pirapora','Barbacena','Patrocínio','Aimorés','Diamantina',
                     'Campo Belo','Ouro Preto','Pedra Azul','Belo Horizonte','Cuiabá','Santa Rita do Sapucaí','Francisco Beltrão','Ipatinga',
                     'Rosário Oeste','Andrelândia','Iporá','Conselheiro Lafaiete','Itajubá','Mantena','Pará de Minas','Vão do Paranã','Telêmaco Borba',
                     'Pato Branco','São Lourenço','Cerro Azul','Capanema','Varginha','Lavras','Manhuaçu','Pitanga','Grão Mogol','Paranaguá','Bananal',
                     'Bodoquena','Guaratinguetá','Guarapuava','União da Vitória','Canarana','Chapada dos Veadeiros','Pouso Alegre','Capão Bonito',
                     'Aquidauana','Pires do Rio','Alto Guaporé','Paraibuna/Paraitinga','Jundiaí','Tesouro','Rio Vermelho','Piedade','Curitiba',
                     'Prudentópolis','Umarizal','Colíder','São Miguel do Araguaia','Baixo Pantanal','Médio Araguaia','Sinop','Registro','Paranatinga',
                     'Jaguariaíva','Palmas','Primavera do Leste','Itapecerica da Serra','Alta Floresta','Mogi das Cruzes','Miracema do Tocantins',
                     'Norte Araguaia','Alagoinhas','São Mateus do Sul','São Paulo','Campos do Jordão','Franco da Rocha'],
    'uf': ['SP','SP','SP','SP','SP','SP','MS','SP','SP','GO','MG','GO','MG','SP','SP','SP','GO','SP','SP','SP','SP','MS','SP','PR','SP','SP','SP','MT',
           'PR','SP','GO','SP','PR','SP','SP','SP','GO','SP','SP','SP','SP','MG','SP','PR','MG','MS','SP','SP','SP','MG','SP','MG','SP','PR','SP','SP',
           'MT','SP','MS','SP','SP','MT','GO','PR','SP','MG','MS','SP','PR','MG','MG','PR','MT','GO','MG','SP','MG','GO','MT','MG','MS','MG','MG','MS',
           'PR','SP','MG','PR','MG','PR','PR','SP','GO','GO','GO','MT','PR','MT','PR','MS','MG','MG','PR','MG','PR','GO','PR','MG','SP','SP','MG','MG',
           'MG','MG','MG','MG','MG','MG','MG','MG','GO','PR','MG','PR','MG','MT','PR','MG','MG','MG','MG','MG','MG','MG','MG','MG','PR','MG','SP','MT',
           'MG','MG','MT','MG','MG','MG','MG','MG','MG','MG','MG','MG','MG','MT','MG','PR','MG','MT','MG','GO','MG','MG','MG','MG','GO','PR','PR','MG',
           'PR','PR','MG','MG','MG','PR','MG','PR','SP','MS','SP','PR','PR','MT','GO','MG','SP','MS','GO','MT','SP','SP','MT','GO','SP','PR','PR','MG',
           'MT','GO','MS','MT','MT','SP','MT','PR','PR','MT','SP','MT','SP','PR','MT','MG','PR','SP','SP','SP']
})

# %% [markdown]
# ## 1.1 Informações do DataFrame:

# %%
microrregiao_prod_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_microrregiao   216 non-null    object
#  1   volume_produzido  216 non-null    Int64
#  2   microrregiao      216 non-null    object
#  3   uf                216 non-null    object
# dtypes: Int64(1), object(3)
# memory usage: 7.1+ KB

# %%
# Convertendo os dados da coluna "volume_produzido" em inteiro:
microrregiao_prod_df["volume_produzido"] = microrregiao_prod_df["volume_produzido"].astype("Int64")

# %% [markdown]
# ## 1.2 Visualização inicial dos dados:

# %% [markdown]
# A visualização das primeiras 15 linhas permite verificar a
# estrutura dos dados, a consistência dos valores e a tipagem
# das colunas definidas.

# %%
microrregiao_prod_df.head(15)
# Out:
#    id_microrregiao  volume_produzido           microrregiao  uf
# 0            35004         473721695  São José do Rio Preto  SP
# 1            35010         377615223   São Joaquim da Barra  SP
# 2            35014         362846755         Ribeirão Preto  SP
# 3            35036         320732162    Presidente Prudente  SP
# 4            35024         312307290             Araraquara  SP
# 5            35013         310754371            Jaboticabal  SP
# 6            50010         293544328               Dourados  MS
# 7            35039         253622427                  Assis  SP
# 8            35021         245591114                    Jaú  SP
# 9            52015         239380119             Meia Ponte  GO
# 10           31022         239341752                Uberaba  MG
# 11           52013         234537856      Sudoeste de Goiás  GO
# 12           31021         227733259                 Frutal  MG
# 13           35017         210628527              Araçatuba  SP
# ...
